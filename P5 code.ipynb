# %% [markdown]
# # PART 1 & 2

# %%
import copy
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split

# Xavier Initialization Function
def init_weights_xavier(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_normal_(m.weight)
        if m.bias is not None:
            nn.init.zeros_(m.bias)

# 1) Data Loading
train_dataset = torchvision.datasets.FashionMNIST(
    'data/', train=True, download=True,
    transform=torchvision.transforms.Compose([
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize((0.1307,), (0.3081,))
    ])
)

test_dataset = torchvision.datasets.FashionMNIST(
    'data/', train=False, download=True,
    transform=torchvision.transforms.Compose([
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize((0.1307,), (0.3081,))
    ])
)

# Create a validation set (10% of the training set)
train_indices, val_indices, _, _ = train_test_split(
    range(len(train_dataset)),
    train_dataset.targets,
    stratify=train_dataset.targets,
    test_size=0.1,
)

train_split = Subset(train_dataset, train_indices)
val_split   = Subset(train_dataset, val_indices)

train_batch_size = 128
test_batch_size  = 256

train_loader = DataLoader(train_split, batch_size=train_batch_size, shuffle=True)
val_loader   = DataLoader(val_split,   batch_size=train_batch_size, shuffle=True)
test_loader  = DataLoader(test_dataset, batch_size=test_batch_size, shuffle=False)

# 2) Define an FCN Model with a parameter check
class FCN(nn.Module):
    def __init__(self, input_dim=784, hidden_dims=[96, 48], output_dim=10, dropout_rate=0.3):
        super(FCN, self).__init__()
        layers = []
        all_dims = [input_dim] + hidden_dims + [output_dim]

        total_params = 0
        for i in range(len(all_dims) - 1):
            layer = nn.Linear(all_dims[i], all_dims[i + 1])
            # Count parameters for the layer
            total_params += all_dims[i] * all_dims[i + 1] + all_dims[i + 1]
            layers.append(layer)
            
            # For hidden layers, apply BatchNorm, ReLU, Dropout
            if i < len(all_dims) - 2:
                layers.append(nn.BatchNorm1d(all_dims[i + 1]))
                layers.append(nn.ReLU())
                layers.append(nn.Dropout(dropout_rate))

        print(f"Model with hidden_dims={hidden_dims}: total_params={total_params}")
        self.network = nn.Sequential(*layers)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten input
        return self.network(x)

# 3) Train & Evaluate a Single Model
def train_and_evaluate(hidden_dims, learning_rates, num_epochs=30, dropout_rate=0.3):
    """
    Trains a model with the given hidden_dims over multiple learning rates.
    Returns the best model state (based on val accuracy), plus metrics.
    """
    best_val_acc_global = 0.0
    best_epoch_global   = 0
    best_lr_global      = None

    best_train_losses      = []
    best_val_losses        = []
    best_train_accuracies  = []
    best_val_accuracies    = []
    best_model_state       = None

    for lr in learning_rates:
        print(f"\n  Training with Learning Rate = {lr}")
        
        # Re-initialize the model from scratch
        model = FCN(input_dim=784, hidden_dims=hidden_dims, output_dim=10, dropout_rate=dropout_rate).to(device)
        model.apply(init_weights_xavier)
        
        # Optimizer & Scheduler
        optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)
        
        criterion = nn.CrossEntropyLoss()
        
        # Lists to track metrics per epoch for THIS LR
        train_losses = []
        val_losses   = []
        train_accuracies = []
        val_accuracies   = []
        
        best_val_acc_local = 0.0
        best_epoch_local   = 0
        best_state_local   = None
        
        for epoch in range(num_epochs):
            # Training phase
            model.train()
            running_loss, correct_train, total_train = 0.0, 0, 0

            for images, labels in train_loader:
                images, labels = images.to(device), labels.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                running_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                correct_train += (predicted == labels).sum().item()
                total_train += labels.size(0)

            train_loss = running_loss / len(train_loader)
            train_acc  = correct_train / total_train

            train_losses.append(train_loss)
            train_accuracies.append(train_acc)

            # Validation phase
            model.eval()
            val_correct, val_total, val_running_loss = 0, 0, 0.0
            with torch.no_grad():
                for images, labels in val_loader:
                    images, labels = images.to(device), labels.to(device)
                    outputs = model(images)
                    loss = criterion(outputs, labels)
                    val_running_loss += loss.item()
                    _, predicted = torch.max(outputs, 1)
                    val_correct += (predicted == labels).sum().item()
                    val_total += labels.size(0)

            val_loss = val_running_loss / len(val_loader)
            val_acc  = val_correct / val_total

            val_losses.append(val_loss)
            val_accuracies.append(val_acc)

            # Update best validation accuracy for THIS LR
            if val_acc > best_val_acc_local:
                best_val_acc_local = val_acc
                best_epoch_local   = epoch + 1
                best_state_local   = copy.deepcopy(model.state_dict())

            # Step the scheduler
            scheduler.step()

            # Print training info
            print(f"    Epoch [{epoch+1}/{num_epochs}] "
                  f"Train Loss: {train_loss:.4f}  Train Acc: {train_acc:.4f} "
                  f"Val Loss: {val_loss:.4f}  Val Acc: {val_acc:.4f}")

        # After finishing all epochs for this LR, check if it's better than global best
        if best_val_acc_local > best_val_acc_global:
            best_val_acc_global = best_val_acc_local
            best_epoch_global   = best_epoch_local
            best_lr_global      = lr
            
            best_train_losses      = train_losses
            best_val_losses        = val_losses
            best_train_accuracies  = train_accuracies
            best_val_accuracies    = val_accuracies
            
            best_model_state = best_state_local

    return {
        'best_val_acc': best_val_acc_global,
        'best_epoch':   best_epoch_global,
        'best_lr':      best_lr_global,
        'train_losses': best_train_losses,
        'val_losses':   best_val_losses,
        'train_accs':   best_train_accuracies,
        'val_accs':     best_val_accuracies,
        'best_model':   best_model_state
    }

# 4) Compare Three FCN Variants: ~50K, ~100K, ~200K
model_configs = {
    "FCN_50K":  [64, 32],
    "FCN_100K": [96, 48],
    "FCN_200K": [224, 112]
}

lrs = [0.001, 0.0005, 0.0001]
num_epochs = 20
dropout_rate = 0.3

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

results = {}

for model_name, hidden_dims in model_configs.items():
    print(f"\nTraining {model_name}:")
    outcome = train_and_evaluate(
        hidden_dims=hidden_dims,
        learning_rates=lrs,
        num_epochs=num_epochs,
        dropout_rate=dropout_rate
    )
    results[model_name] = outcome

    # Once we have the best model for this variant, evaluate on the test set
    best_model = FCN(input_dim=784, hidden_dims=hidden_dims, 
                     output_dim=10, dropout_rate=dropout_rate).to(device)
    best_model.load_state_dict(outcome['best_model'])
    best_model.eval()

    test_correct, test_total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = best_model(images)
            _, predicted = torch.max(outputs, 1)
            test_correct += (predicted == labels).sum().item()
            test_total   += labels.size(0)

    test_acc = test_correct / test_total
    print(f"--- {model_name} Results ---")
    print(f"Best Learning Rate: {outcome['best_lr']}")
    print(f"Best Validation Accuracy: {outcome['best_val_acc']:.4f} "
          f"(Epoch {outcome['best_epoch']})")
    print(f"Test Accuracy: {test_acc:.4f}\n")

    # 5) Plot only for this model’s best run
    epochs_range = range(1, num_epochs + 1)
    plt.figure(figsize=(10,6))
    plt.plot(epochs_range, outcome['train_losses'], 'o-', label='Train Loss', color='blue')
    plt.plot(epochs_range, outcome['val_losses'],   'o-', label='Validation Loss', color='red')
    plt.plot(epochs_range, outcome['train_accs'],   'o-', label='Train Accuracy', color='green')
    plt.plot(epochs_range, outcome['val_accs'],     'o-', label='Validation Accuracy', color='orange')

    plt.axvline(x=outcome['best_epoch'], color='black', linestyle='--',
                label=f'Best Val Acc (Epoch {outcome["best_epoch"]})')

    plt.title(f"{model_name} (Best LR={outcome['best_lr']})")
    plt.xlabel('Epoch')
    plt.ylabel('Loss / Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# Training FCN_50K:
#
#   Training with Learning Rate = 0.001
# Model with hidden_dims=[64, 32]: total_params=52650
#     Epoch [1/20] Train Loss: 0.8736  Train Acc: 0.7226 Val Loss: 0.4569  Val Acc: 0.8447
#     Epoch [2/20] Train Loss: 0.5726  Train Acc: 0.8066 Val Loss: 0.4032  Val Acc: 0.8557
#     Epoch [3/20] Train Loss: 0.5116  Train Acc: 0.8262 Val Loss: 0.3833  Val Acc: 0.8623
#     Epoch [4/20] Train Loss: 0.4831  Train Acc: 0.8331 Val Loss: 0.3743  Val Acc: 0.8640
#     Epoch [5/20] Train Loss: 0.4590  Train Acc: 0.8414 Val Loss: 0.3620  Val Acc: 0.8658
#     Epoch [6/20] Train Loss: 0.4483  Train Acc: 0.8452 Val Loss: 0.3583  Val Acc: 0.8700
#     Epoch [7/20] Train Loss: 0.4279  Train Acc: 0.8530 Val Loss: 0.3477  Val Acc: 0.8713
#     Epoch [8/20] Train Loss: 0.4229  Train Acc: 0.8543 Val Loss: 0.3515  Val Acc: 0.8735
#     Epoch [9/20] Train Loss: 0.4105  Train Acc: 0.8565 Val Loss: 0.3458  Val Acc: 0.8778
#     Epoch [10/20] Train Loss: 0.4018  Train Acc: 0.8592 Val Loss: 0.3424  Val Acc: 0.8757
#     Epoch [11/20] Train Loss: 0.3840  Train Acc: 0.8663 Val Loss: 0.3307  Val Acc: 0.8802
#     Epoch [12/20] Train Loss: 0.3751  Train Acc: 0.8694 Val Loss: 0.3295  Val Acc: 0.8818
#     Epoch [13/20] Train Loss: 0.3715  Train Acc: 0.8704 Val Loss: 0.3268  Val Acc: 0.8825
#     Epoch [14/20] Train Loss: 0.3682  Train Acc: 0.8705 Val Loss: 0.3311  Val Acc: 0.8825
#     Epoch [15/20] Train Loss: 0.3646  Train Acc: 0.8713 Val Loss: 0.3253  Val Acc: 0.8832
#     Epoch [16/20] Train Loss: 0.3633  Train Acc: 0.8725 Val Loss: 0.3268  Val Acc: 0.8825
#     Epoch [17/20] Train Loss: 0.3622  Train Acc: 0.8728 Val Loss: 0.3223  Val Acc: 0.8843
#     Epoch [18/20] Train Loss: 0.3565  Train Acc: 0.8755 Val Loss: 0.3261  Val Acc: 0.8818
#     Epoch [19/20] Train Loss: 0.3541  Train Acc: 0.8770 Val Loss: 0.3258  Val Acc: 0.8848
#     Epoch [20/20] Train Loss: 0.3516  Train Acc: 0.8756 Val Loss: 0.3204  Val Acc: 0.8867
#
#   Training with Learning Rate = 0.0005
# Model with hidden_dims=[64, 32]: total_params=52650
#     Epoch [1/20] Train Loss: 1.0195  Train Acc: 0.6820 Val Loss: 0.5351  Val Acc: 0.8287
#     Epoch [2/20] Train Loss: 0.6544  Train Acc: 0.7875 Val Loss: 0.4398  Val Acc: 0.8407
#     Epoch [3/20] Train Loss: 0.5728  Train Acc: 0.8073 Val Loss: 0.4069  Val Acc: 0.8532
#     Epoch [4/20] Train Loss: 0.5259  Train Acc: 0.8211 Val Loss: 0.3948  Val Acc: 0.8555
#     Epoch [5/20] Train Loss: 0.5004  Train Acc: 0.8292 Val Loss: 0.3794  Val Acc: 0.8590
#     Epoch [6/20] Train Loss: 0.4803  Train Acc: 0.8363 Val Loss: 0.3694  Val Acc: 0.8635
#     Epoch [7/20] Train Loss: 0.4627  Train Acc: 0.8423 Val Loss: 0.3672  Val Acc: 0.8618
#     Epoch [8/20] Train Loss: 0.4501  Train Acc: 0.8453 Val Loss: 0.3563  Val Acc: 0.8685
#     Epoch [9/20] Train Loss: 0.4385  Train Acc: 0.8487 Val Loss: 0.3521  Val Acc: 0.8688
#     Epoch [10/20] Train Loss: 0.4310  Train Acc: 0.8504 Val Loss: 0.3462  Val Acc: 0.8697
#     Epoch [11/20] Train Loss: 0.4117  Train Acc: 0.8560 Val Loss: 0.3412  Val Acc: 0.8737
#     Epoch [12/20] Train Loss: 0.4074  Train Acc: 0.8590 Val Loss: 0.3411  Val Acc: 0.8722
#     Epoch [13/20] Train Loss: 0.4071  Train Acc: 0.8588 Val Loss: 0.3381  Val Acc: 0.8755
#     Epoch [14/20] Train Loss: 0.3994  Train Acc: 0.8609 Val Loss: 0.3324  Val Acc: 0.8778
#     Epoch [15/20] Train Loss: 0.3982  Train Acc: 0.8619 Val Loss: 0.3336  Val Acc: 0.8772
#     Epoch [16/20] Train Loss: 0.3915  Train Acc: 0.8624 Val Loss: 0.3335  Val Acc: 0.8772
#     Epoch [17/20] Train Loss: 0.3900  Train Acc: 0.8638 Val Loss: 0.3314  Val Acc: 0.8797
#     Epoch [18/20] Train Loss: 0.3891  Train Acc: 0.8656 Val Loss: 0.3318  Val Acc: 0.8792
#     Epoch [19/20] Train Loss: 0.3846  Train Acc: 0.8657 Val Loss: 0.3324  Val Acc: 0.8767
#     Epoch [20/20] Train Loss: 0.3798  Train Acc: 0.8681 Val Loss: 0.3287  Val Acc: 0.8802
#
#   Training with Learning Rate = 0.0001
# Model with hidden_dims=[64, 32]: total_params=52650
#     Epoch [1/20] Train Loss: 1.6471  Train Acc: 0.4657 Val Loss: 1.0292  Val Acc: 0.7497
#     Epoch [2/20] Train Loss: 1.1084  Train Acc: 0.6771 Val Loss: 0.7805  Val Acc: 0.7938
#     Epoch [3/20] Train Loss: 0.9164  Train Acc: 0.7328 Val Loss: 0.6487  Val Acc: 0.8145
#     Epoch [4/20] Train Loss: 0.8093  Train Acc: 0.7551 Val Loss: 0.5699  Val Acc: 0.8253
#     Epoch [5/20] Train Loss: 0.7405  Train Acc: 0.7701 Val Loss: 0.5198  Val Acc: 0.8348
#     Epoch [6/20] Train Loss: 0.6884  Train Acc: 0.7821 Val Loss: 0.4866  Val Acc: 0.8390
#     Epoch [7/20] Train Loss: 0.6499  Train Acc: 0.7908 Val Loss: 0.4646  Val Acc: 0.8442
#     Epoch [8/20] Train Loss: 0.6196  Train Acc: 0.7985 Val Loss: 0.4478  Val Acc: 0.8462
#     Epoch [9/20] Train Loss: 0.5988  Train Acc: 0.8024 Val Loss: 0.4341  Val Acc: 0.8455
#     Epoch [10/20] Train Loss: 0.5781  Train Acc: 0.8098 Val Loss: 0.4228  Val Acc: 0.8485
#     Epoch [11/20] Train Loss: 0.5693  Train Acc: 0.8119 Val Loss: 0.4157  Val Acc: 0.8530
#     Epoch [12/20] Train Loss: 0.5609  Train Acc: 0.8123 Val Loss: 0.4124  Val Acc: 0.8515
#     Epoch [13/20] Train Loss: 0.5484  Train Acc: 0.8170 Val Loss: 0.4095  Val Acc: 0.8508
#     Epoch [14/20] Train Loss: 0.5420  Train Acc: 0.8186 Val Loss: 0.4040  Val Acc: 0.8573
#     Epoch [15/20] Train Loss: 0.5367  Train Acc: 0.8194 Val Loss: 0.4021  Val Acc: 0.8555
#     Epoch [16/20] Train Loss: 0.5326  Train Acc: 0.8203 Val Loss: 0.3986  Val Acc: 0.8583
#     Epoch [17/20] Train Loss: 0.5250  Train Acc: 0.8231 Val Loss: 0.3960  Val Acc: 0.8568
#     Epoch [18/20] Train Loss: 0.5218  Train Acc: 0.8227 Val Loss: 0.3935  Val Acc: 0.8582
#     Epoch [19/20] Train Loss: 0.5184  Train Acc: 0.8238 Val Loss: 0.3916  Val Acc: 0.8608
#     Epoch [20/20] Train Loss: 0.5156  Train Acc: 0.8244 Val Loss: 0.3888  Val Acc: 0.8622
# Model with hidden_dims=[64, 32]: total_params=52650
# --- FCN_50K Results ---
# Best Learning Rate: 0.001
# Best Validation Accuracy: 0.8867 (Epoch 20)
# Test Accuracy: 0.8794
# Training FCN_100K:
#
#   Training with Learning Rate = 0.001
# Model with hidden_dims=[96, 48]: total_params=80506
#     Epoch [1/20] Train Loss: 0.7383  Train Acc: 0.7586 Val Loss: 0.4406  Val Acc: 0.8372
#     Epoch [2/20] Train Loss: 0.4991  Train Acc: 0.8281 Val Loss: 0.3800  Val Acc: 0.8590
#     Epoch [3/20] Train Loss: 0.4513  Train Acc: 0.8425 Val Loss: 0.3688  Val Acc: 0.8690
#     Epoch [4/20] Train Loss: 0.4240  Train Acc: 0.8491 Val Loss: 0.3546  Val Acc: 0.8752
#     Epoch [5/20] Train Loss: 0.4061  Train Acc: 0.8558 Val Loss: 0.3420  Val Acc: 0.8777
#     Epoch [6/20] Train Loss: 0.3921  Train Acc: 0.8600 Val Loss: 0.3369  Val Acc: 0.8823
#     Epoch [7/20] Train Loss: 0.3735  Train Acc: 0.8678 Val Loss: 0.3368  Val Acc: 0.8808
#     Epoch [8/20] Train Loss: 0.3642  Train Acc: 0.8720 Val Loss: 0.3279  Val Acc: 0.8825
#     Epoch [9/20] Train Loss: 0.3592  Train Acc: 0.8708 Val Loss: 0.3204  Val Acc: 0.8858
#     Epoch [10/20] Train Loss: 0.3493  Train Acc: 0.8769 Val Loss: 0.3303  Val Acc: 0.8792
#     Epoch [11/20] Train Loss: 0.3292  Train Acc: 0.8814 Val Loss: 0.3148  Val Acc: 0.8902
#     Epoch [12/20] Train Loss: 0.3215  Train Acc: 0.8846 Val Loss: 0.3084  Val Acc: 0.8905
#     Epoch [13/20] Train Loss: 0.3218  Train Acc: 0.8836 Val Loss: 0.3072  Val Acc: 0.8913
#     Epoch [14/20] Train Loss: 0.3136  Train Acc: 0.8874 Val Loss: 0.3040  Val Acc: 0.8893
#     Epoch [15/20] Train Loss: 0.3091  Train Acc: 0.8883 Val Loss: 0.3008  Val Acc: 0.8912
#     Epoch [16/20] Train Loss: 0.3064  Train Acc: 0.8885 Val Loss: 0.3038  Val Acc: 0.8920
#     Epoch [17/20] Train Loss: 0.2978  Train Acc: 0.8914 Val Loss: 0.3038  Val Acc: 0.8903
#     Epoch [18/20] Train Loss: 0.2985  Train Acc: 0.8923 Val Loss: 0.2991  Val Acc: 0.8933
#     Epoch [19/20] Train Loss: 0.2975  Train Acc: 0.8935 Val Loss: 0.3069  Val Acc: 0.8897
#     Epoch [20/20] Train Loss: 0.2938  Train Acc: 0.8937 Val Loss: 0.3048  Val Acc: 0.8908
#
#   Training with Learning Rate = 0.0005
# Model with hidden_dims=[96, 48]: total_params=80506
#     Epoch [1/20] Train Loss: 0.8915  Train Acc: 0.7127 Val Loss: 0.4856  Val Acc: 0.8397
#     Epoch [2/20] Train Loss: 0.5668  Train Acc: 0.8096 Val Loss: 0.4158  Val Acc: 0.8543
#     Epoch [3/20] Train Loss: 0.5021  Train Acc: 0.8267 Val Loss: 0.3930  Val Acc: 0.8567
#     Epoch [4/20] Train Loss: 0.4644  Train Acc: 0.8401 Val Loss: 0.3725  Val Acc: 0.8600
#     Epoch [5/20] Train Loss: 0.4371  Train Acc: 0.8471 Val Loss: 0.3627  Val Acc: 0.8723
#     Epoch [6/20] Train Loss: 0.4200  Train Acc: 0.8513 Val Loss: 0.3553  Val Acc: 0.8728
#     Epoch [7/20] Train Loss: 0.4071  Train Acc: 0.8569 Val Loss: 0.3450  Val Acc: 0.8763
#     Epoch [8/20] Train Loss: 0.3944  Train Acc: 0.8601 Val Loss: 0.3468  Val Acc: 0.8743
#     Epoch [9/20] Train Loss: 0.3838  Train Acc: 0.8643 Val Loss: 0.3305  Val Acc: 0.8798
#     Epoch [10/20] Train Loss: 0.3718  Train Acc: 0.8686 Val Loss: 0.3315  Val Acc: 0.8812
#     Epoch [11/20] Train Loss: 0.3533  Train Acc: 0.8741 Val Loss: 0.3217  Val Acc: 0.8862
#     Epoch [12/20] Train Loss: 0.3463  Train Acc: 0.8768 Val Loss: 0.3219  Val Acc: 0.8860
#     Epoch [13/20] Train Loss: 0.3448  Train Acc: 0.8761 Val Loss: 0.3147  Val Acc: 0.8877
#     Epoch [14/20] Train Loss: 0.3398  Train Acc: 0.8782 Val Loss: 0.3122  Val Acc: 0.8882
#     Epoch [15/20] Train Loss: 0.3358  Train Acc: 0.8799 Val Loss: 0.3153  Val Acc: 0.8867
#     Epoch [16/20] Train Loss: 0.3319  Train Acc: 0.8817 Val Loss: 0.3120  Val Acc: 0.8917
#     Epoch [17/20] Train Loss: 0.3276  Train Acc: 0.8822 Val Loss: 0.3086  Val Acc: 0.8900
#     Epoch [18/20] Train Loss: 0.3233  Train Acc: 0.8846 Val Loss: 0.3111  Val Acc: 0.8917
#     Epoch [19/20] Train Loss: 0.3206  Train Acc: 0.8864 Val Loss: 0.3079  Val Acc: 0.8893
#     Epoch [20/20] Train Loss: 0.3192  Train Acc: 0.8863 Val Loss: 0.3048  Val Acc: 0.8927
#
#   Training with Learning Rate = 0.0001
# Model with hidden_dims=[96, 48]: total_params=80506
#     Epoch [1/20] Train Loss: 1.3454  Train Acc: 0.5661 Val Loss: 0.7899  Val Acc: 0.7820
#     Epoch [2/20] Train Loss: 0.8690  Train Acc: 0.7349 Val Loss: 0.6064  Val Acc: 0.8138
#     Epoch [3/20] Train Loss: 0.7281  Train Acc: 0.7721 Val Loss: 0.5273  Val Acc: 0.8315
#     Epoch [4/20] Train Loss: 0.6509  Train Acc: 0.7926 Val Loss: 0.4778  Val Acc: 0.8373
#     Epoch [5/20] Train Loss: 0.6007  Train Acc: 0.8058 Val Loss: 0.4469  Val Acc: 0.8460
#     Epoch [6/20] Train Loss: 0.5677  Train Acc: 0.8103 Val Loss: 0.4279  Val Acc: 0.8498
#     Epoch [7/20] Train Loss: 0.5397  Train Acc: 0.8189 Val Loss: 0.4147  Val Acc: 0.8513
#     Epoch [8/20] Train Loss: 0.5205  Train Acc: 0.8264 Val Loss: 0.4013  Val Acc: 0.8565
#     Epoch [9/20] Train Loss: 0.5011  Train Acc: 0.8301 Val Loss: 0.3915  Val Acc: 0.8603
#     Epoch [10/20] Train Loss: 0.4878  Train Acc: 0.8335 Val Loss: 0.3869  Val Acc: 0.8620
#     Epoch [11/20] Train Loss: 0.4779  Train Acc: 0.8379 Val Loss: 0.3819  Val Acc: 0.8615
#     Epoch [12/20] Train Loss: 0.4700  Train Acc: 0.8404 Val Loss: 0.3775  Val Acc: 0.8652
#     Epoch [13/20] Train Loss: 0.4667  Train Acc: 0.8410 Val Loss: 0.3756  Val Acc: 0.8655
#     Epoch [14/20] Train Loss: 0.4586  Train Acc: 0.8426 Val Loss: 0.3722  Val Acc: 0.8658
#     Epoch [15/20] Train Loss: 0.4542  Train Acc: 0.8431 Val Loss: 0.3693  Val Acc: 0.8673
#     Epoch [16/20] Train Loss: 0.4504  Train Acc: 0.8456 Val Loss: 0.3685  Val Acc: 0.8673
#     Epoch [17/20] Train Loss: 0.4485  Train Acc: 0.8457 Val Loss: 0.3637  Val Acc: 0.8698
#     Epoch [18/20] Train Loss: 0.4442  Train Acc: 0.8461 Val Loss: 0.3613  Val Acc: 0.8708
#     Epoch [19/20] Train Loss: 0.4395  Train Acc: 0.8481 Val Loss: 0.3604  Val Acc: 0.8658
#     Epoch [20/20] Train Loss: 0.4369  Train Acc: 0.8493 Val Loss: 0.3586  Val Acc: 0.8707
# Model with hidden_dims=[96, 48]: total_params=80506
# --- FCN_100K Results ---
# Best Learning Rate: 0.001
# Best Validation Accuracy: 0.8933 (Epoch 18)
# Test Accuracy: 0.8825
# Training FCN_200K:
#
#   Training with Learning Rate = 0.001
# Model with hidden_dims=[224, 112]: total_params=202170
#     Epoch [1/20] Train Loss: 0.5867  Train Acc: 0.7951 Val Loss: 0.4117  Val Acc: 0.8517
#     Epoch [2/20] Train Loss: 0.4222  Train Acc: 0.8487 Val Loss: 0.3636  Val Acc: 0.8658
#     Epoch [3/20] Train Loss: 0.3848  Train Acc: 0.8614 Val Loss: 0.3313  Val Acc: 0.8823
#     Epoch [4/20] Train Loss: 0.3600  Train Acc: 0.8699 Val Loss: 0.3267  Val Acc: 0.8808
#     Epoch [5/20] Train Loss: 0.3359  Train Acc: 0.8763 Val Loss: 0.3145  Val Acc: 0.8900
#     Epoch [6/20] Train Loss: 0.3229  Train Acc: 0.8814 Val Loss: 0.3282  Val Acc: 0.8825
#     Epoch [7/20] Train Loss: 0.3152  Train Acc: 0.8830 Val Loss: 0.3061  Val Acc: 0.8892
#     Epoch [8/20] Train Loss: 0.2997  Train Acc: 0.8894 Val Loss: 0.3010  Val Acc: 0.8940
#     Epoch [9/20] Train Loss: 0.2881  Train Acc: 0.8935 Val Loss: 0.3033  Val Acc: 0.8880
#     Epoch [10/20] Train Loss: 0.2863  Train Acc: 0.8946 Val Loss: 0.3015  Val Acc: 0.8890
#     Epoch [11/20] Train Loss: 0.2575  Train Acc: 0.9043 Val Loss: 0.2904  Val Acc: 0.8950
#     Epoch [12/20] Train Loss: 0.2485  Train Acc: 0.9072 Val Loss: 0.2885  Val Acc: 0.8945
#     Epoch [13/20] Train Loss: 0.2436  Train Acc: 0.9094 Val Loss: 0.2838  Val Acc: 0.9007
#     Epoch [14/20] Train Loss: 0.2395  Train Acc: 0.9112 Val Loss: 0.2789  Val Acc: 0.8968
#     Epoch [15/20] Train Loss: 0.2354  Train Acc: 0.9123 Val Loss: 0.2873  Val Acc: 0.8995
#     Epoch [16/20] Train Loss: 0.2307  Train Acc: 0.9148 Val Loss: 0.2818  Val Acc: 0.8985
#     Epoch [17/20] Train Loss: 0.2210  Train Acc: 0.9184 Val Loss: 0.2886  Val Acc: 0.8965
#     Epoch [18/20] Train Loss: 0.2222  Train Acc: 0.9171 Val Loss: 0.2986  Val Acc: 0.8985
#     Epoch [19/20] Train Loss: 0.2196  Train Acc: 0.9164 Val Loss: 0.2810  Val Acc: 0.9015
#     Epoch [20/20] Train Loss: 0.2116  Train Acc: 0.9212 Val Loss: 0.2832  Val Acc: 0.9007
#
#   Training with Learning Rate = 0.0005
# Model with hidden_dims=[224, 112]: total_params=202170
#     Epoch [1/20] Train Loss: 0.6570  Train Acc: 0.7773 Val Loss: 0.4066  Val Acc: 0.8542
#     Epoch [2/20] Train Loss: 0.4502  Train Acc: 0.8404 Val Loss: 0.3694  Val Acc: 0.8645
#     Epoch [3/20] Train Loss: 0.4063  Train Acc: 0.8545 Val Loss: 0.3479  Val Acc: 0.8732
#     Epoch [4/20] Train Loss: 0.3765  Train Acc: 0.8632 Val Loss: 0.3319  Val Acc: 0.8792
#     Epoch [5/20] Train Loss: 0.3588  Train Acc: 0.8697 Val Loss: 0.3441  Val Acc: 0.8748
#     Epoch [6/20] Train Loss: 0.3411  Train Acc: 0.8759 Val Loss: 0.3184  Val Acc: 0.8818
#     Epoch [7/20] Train Loss: 0.3250  Train Acc: 0.8813 Val Loss: 0.3099  Val Acc: 0.8882
#     Epoch [8/20] Train Loss: 0.3160  Train Acc: 0.8845 Val Loss: 0.3005  Val Acc: 0.8893
#     Epoch [9/20] Train Loss: 0.3026  Train Acc: 0.8893 Val Loss: 0.3011  Val Acc: 0.8910
#     Epoch [10/20] Train Loss: 0.2974  Train Acc: 0.8907 Val Loss: 0.3088  Val Acc: 0.8883
#     Epoch [11/20] Train Loss: 0.2757  Train Acc: 0.8982 Val Loss: 0.2919  Val Acc: 0.8932
#     Epoch [12/20] Train Loss: 0.2681  Train Acc: 0.9014 Val Loss: 0.2882  Val Acc: 0.8947
#     Epoch [13/20] Train Loss: 0.2610  Train Acc: 0.9045 Val Loss: 0.2892  Val Acc: 0.8943
#     Epoch [14/20] Train Loss: 0.2568  Train Acc: 0.9059 Val Loss: 0.2875  Val Acc: 0.8938
#     Epoch [15/20] Train Loss: 0.2515  Train Acc: 0.9074 Val Loss: 0.2989  Val Acc: 0.8970
#     Epoch [16/20] Train Loss: 0.2478  Train Acc: 0.9080 Val Loss: 0.2872  Val Acc: 0.8963
#     Epoch [17/20] Train Loss: 0.2447  Train Acc: 0.9104 Val Loss: 0.2802  Val Acc: 0.8965
#     Epoch [18/20] Train Loss: 0.2370  Train Acc: 0.9125 Val Loss: 0.2868  Val Acc: 0.8928
#     Epoch [19/20] Train Loss: 0.2338  Train Acc: 0.9136 Val Loss: 0.2827  Val Acc: 0.8973
#     Epoch [20/20] Train Loss: 0.2324  Train Acc: 0.9158 Val Loss: 0.2811  Val Acc: 0.8992
#
#   Training with Learning Rate = 0.0001
# Model with hidden_dims=[224, 112]: total_params=202170
#     Epoch [1/20] Train Loss: 1.0056  Train Acc: 0.6633 Val Loss: 0.5546  Val Acc: 0.8097
#     Epoch [2/20] Train Loss: 0.6214  Train Acc: 0.7879 Val Loss: 0.4605  Val Acc: 0.8397
#     Epoch [3/20] Train Loss: 0.5377  Train Acc: 0.8135 Val Loss: 0.4205  Val Acc: 0.8490
#     Epoch [4/20] Train Loss: 0.4932  Train Acc: 0.8286 Val Loss: 0.3977  Val Acc: 0.8582
#     Epoch [5/20] Train Loss: 0.4664  Train Acc: 0.8372 Val Loss: 0.3829  Val Acc: 0.8598
#     Epoch [6/20] Train Loss: 0.4464  Train Acc: 0.8434 Val Loss: 0.3705  Val Acc: 0.8645
#     Epoch [7/20] Train Loss: 0.4242  Train Acc: 0.8510 Val Loss: 0.3595  Val Acc: 0.8693
#     Epoch [8/20] Train Loss: 0.4096  Train Acc: 0.8540 Val Loss: 0.3507  Val Acc: 0.8725
#     Epoch [9/20] Train Loss: 0.3998  Train Acc: 0.8574 Val Loss: 0.3448  Val Acc: 0.8753
#     Epoch [10/20] Train Loss: 0.3858  Train Acc: 0.8620 Val Loss: 0.3403  Val Acc: 0.8783
#     Epoch [11/20] Train Loss: 0.3737  Train Acc: 0.8665 Val Loss: 0.3356  Val Acc: 0.8790
#     Epoch [12/20] Train Loss: 0.3674  Train Acc: 0.8688 Val Loss: 0.3329  Val Acc: 0.8792
#     Epoch [13/20] Train Loss: 0.3643  Train Acc: 0.8706 Val Loss: 0.3301  Val Acc: 0.8800
#     Epoch [14/20] Train Loss: 0.3582  Train Acc: 0.8701 Val Loss: 0.3290  Val Acc: 0.8820
#     Epoch [15/20] Train Loss: 0.3572  Train Acc: 0.8726 Val Loss: 0.3251  Val Acc: 0.8815
#     Epoch [16/20] Train Loss: 0.3519  Train Acc: 0.8729 Val Loss: 0.3232  Val Acc: 0.8822
#     Epoch [17/20] Train Loss: 0.3466  Train Acc: 0.8756 Val Loss: 0.3219  Val Acc: 0.8852
#     Epoch [18/20] Train Loss: 0.3429  Train Acc: 0.8761 Val Loss: 0.3192  Val Acc: 0.8840
#     Epoch [19/20] Train Loss: 0.3391  Train Acc: 0.8786 Val Loss: 0.3189  Val Acc: 0.8863
#     Epoch [20/20] Train Loss: 0.3354  Train Acc: 0.8788 Val Loss: 0.3172  Val Acc: 0.8857
# Model with hidden_dims=[224, 112]: total_params=202170
# --- FCN_200K Results ---
# Best Learning Rate: 0.001
# Best Validation Accuracy: 0.9015 (Epoch 19)
# Test Accuracy: 0.8959

# %% [markdown]
# # PART 3 & 4

# %%
import copy
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split

# 1) Data Loading
train_dataset = torchvision.datasets.FashionMNIST(
    'data/', train=True, download=True,
    transform=torchvision.transforms.Compose([
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize((0.1307,), (0.3081,))
    ])
)

test_dataset = torchvision.datasets.FashionMNIST(
    'data/', train=False, download=True,
    transform=torchvision.transforms.Compose([
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize((0.1307,), (0.3081,))
    ])
)

# Create a validation set (10% of the training set)
train_indices, val_indices, _, _ = train_test_split(
    range(len(train_dataset)),
    train_dataset.targets,
    stratify=train_dataset.targets,
    test_size=0.1,
)

train_split = Subset(train_dataset, train_indices)
val_split   = Subset(train_dataset, val_indices)

train_batch_size = 128
test_batch_size  = 256

train_loader = DataLoader(train_split, batch_size=train_batch_size, shuffle=True)
val_loader   = DataLoader(val_split,   batch_size=train_batch_size, shuffle=True)
test_loader  = DataLoader(test_dataset, batch_size=test_batch_size, shuffle=False)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


# 2) Define a CNN class with param sizes close to 10K, 20K, 50K, or 100K
#    using 2 convolutional layers + pooling + 1 fully-connected layer.
class CNN(nn.Module):
    def __init__(self, conv1_out=16, conv2_out=32, fc_dim=120, dropout_rate=0.3):
        super(CNN, self).__init__()
        
        # Convolutional layers
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=conv1_out, kernel_size=3, stride=1, padding=0)
        self.conv2 = nn.Conv2d(in_channels=conv1_out, out_channels=conv2_out, kernel_size=3, stride=1, padding=0)
        
        # Pooling layer
        self.pool  = nn.MaxPool2d(kernel_size=2, stride=2)
        
        # Flatten that into conv2_out * 5 * 5 features
        flatten_dim = conv2_out * 5 * 5
        
        # Fully connected layers
        self.fc1 = nn.Linear(flatten_dim, fc_dim)
        self.fc2 = nn.Linear(fc_dim, 10)
        
        # Other layers
        self.dropout = nn.Dropout(dropout_rate)
        self.relu    = nn.ReLU()
        
        # Print total param count
        total_params = sum(p.numel() for p in self.parameters())
        print(f"CNN with (conv1_out={conv1_out}, conv2_out={conv2_out}, fc_dim={fc_dim}): "
              f"Total params={total_params}")

    def forward(self, x):
        # Convolution + ReLU + Pool (1st block)
        x = self.conv1(x)
        x = self.relu(x)
        x = self.pool(x)
        
        # Convolution + ReLU + Pool (2nd block)
        x = self.conv2(x)
        x = self.relu(x)
        x = self.pool(x)
        
        # Flatten
        x = x.view(x.size(0), -1)
        
        # Fully connected + ReLU + Dropout + final linear
        x = self.fc1(x)
        x = self.relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        
        return x


# 3) Train & Evaluate Function (similar to your FCN approach)
def train_and_evaluate_cnn(conv1_out, conv2_out, fc_dim, learning_rates,
                           num_epochs=20, dropout_rate=0.3):
    """
    Trains a CNN with the given conv/fc dims over multiple learning rates.
    Returns the best model state (based on val accuracy), plus metrics.
    """
    best_val_acc_global = 0.0
    best_epoch_global   = 0
    best_lr_global      = None

    best_train_losses     = []
    best_val_losses       = []
    best_train_accuracies = []
    best_val_accuracies   = []
    best_model_state      = None

    for lr in learning_rates:
        print(f"\n  Training with Learning Rate = {lr}")
        
        # Re-initialize the model from scratch
        model = CNN(conv1_out=conv1_out, conv2_out=conv2_out, fc_dim=fc_dim,
                    dropout_rate=dropout_rate).to(device)
        
        optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-4)
        scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)
        criterion = nn.CrossEntropyLoss()
        
        train_losses     = []
        val_losses       = []
        train_accuracies = []
        val_accuracies   = []
        
        best_val_acc_local = 0.0
        best_epoch_local   = 0
        best_state_local   = None
        
        for epoch in range(num_epochs):
            # Training phase
            model.train()
            running_loss, correct_train, total_train = 0.0, 0, 0

            for images, labels in train_loader:
                images, labels = images.to(device), labels.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

                running_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                correct_train += (predicted == labels).sum().item()
                total_train += labels.size(0)

            train_loss = running_loss / len(train_loader)
            train_acc  = correct_train / total_train
            train_losses.append(train_loss)
            train_accuracies.append(train_acc)

            # Validation phase
            model.eval()
            val_correct, val_total, val_running_loss = 0, 0, 0.0
            with torch.no_grad():
                for images, labels in val_loader:
                    images, labels = images.to(device), labels.to(device)
                    outputs = model(images)
                    loss = criterion(outputs, labels)
                    val_running_loss += loss.item()
                    _, predicted = torch.max(outputs, 1)
                    val_correct += (predicted == labels).sum().item()
                    val_total += labels.size(0)

            val_loss = val_running_loss / len(val_loader)
            val_acc  = val_correct / val_total
            val_losses.append(val_loss)
            val_accuracies.append(val_acc)

            # Update best validation accuracy for THIS LR
            if val_acc > best_val_acc_local:
                best_val_acc_local = val_acc
                best_epoch_local   = epoch + 1
                best_state_local   = copy.deepcopy(model.state_dict())

            scheduler.step()

            print(f"    Epoch [{epoch+1}/{num_epochs}] "
                  f"Train Loss: {train_loss:.4f}  Train Acc: {train_acc:.4f} "
                  f"Val Loss: {val_loss:.4f}  Val Acc: {val_acc:.4f}")

        # After all epochs for this LR, see if it's better than global best
        if best_val_acc_local > best_val_acc_global:
            best_val_acc_global = best_val_acc_local
            best_epoch_global   = best_epoch_local
            best_lr_global      = lr
            
            best_train_losses     = train_losses
            best_val_losses       = val_losses
            best_train_accuracies = train_accuracies
            best_val_accuracies   = val_accuracies
            
            best_model_state = best_state_local

    return {
        'best_val_acc': best_val_acc_global,
        'best_epoch':   best_epoch_global,
        'best_lr':      best_lr_global,
        'train_losses': best_train_losses,
        'val_losses':   best_val_losses,
        'train_accs':   best_train_accuracies,
        'val_accs':     best_val_accuracies,
        'best_model':   best_model_state
    }


# 4) Part 3 & 4: Train CNN 100K/50K/20K/10K, each with 3 LRs
model_configs = {
    # Part 4: smaller models
    "CNN_10K":  (4,  8,  45),   # ~9.8K params
    "CNN_20K":  (6, 12,  60),   # ~19K params
    "CNN_50K":  (8, 16, 120),   # ~50K params
    # Part 3: up to ~100K model
    "CNN_100K": (16, 32, 120)   # ~100K params
}

lrs = [0.001, 0.0005, 0.0001]
num_epochs   = 20
dropout_rate = 0.3

results = {}

for model_name, (c1, c2, fc) in model_configs.items():
    print(f"\nTraining {model_name}:")
    outcome = train_and_evaluate_cnn(
        conv1_out=c1,
        conv2_out=c2,
        fc_dim=fc,
        learning_rates=lrs,
        num_epochs=num_epochs,
        dropout_rate=dropout_rate
    )
    results[model_name] = outcome

    # Load the best model state and evaluate on the test set
    best_model = CNN(conv1_out=c1, conv2_out=c2, fc_dim=fc, dropout_rate=dropout_rate).to(device)
    best_model.load_state_dict(outcome['best_model'])
    best_model.eval()

    test_correct, test_total = 0, 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = best_model(images)
            _, predicted = torch.max(outputs, 1)
            test_correct += (predicted == labels).sum().item()
            test_total   += labels.size(0)

    test_acc = test_correct / test_total

    print(f"--- {model_name} Results ---")
    print(f"Best Learning Rate: {outcome['best_lr']}")
    print(f"Best Validation Accuracy: {outcome['best_val_acc']:.4f} "
          f"(Epoch {outcome['best_epoch']})")
    print(f"Test Accuracy: {test_acc:.4f}\n")

    # Plot training/validation curves for the best run of this model
    epochs_range = range(1, num_epochs + 1)
    plt.figure(figsize=(10,6))
    plt.plot(epochs_range, outcome['train_losses'], 'o-', label='Train Loss', color='blue')
    plt.plot(epochs_range, outcome['val_losses'],   'o-', label='Validation Loss', color='red')
    plt.plot(epochs_range, outcome['train_accs'],   'o-', label='Train Accuracy', color='green')
    plt.plot(epochs_range, outcome['val_accs'],     'o-', label='Validation Accuracy', color='orange')

    plt.axvline(x=outcome['best_epoch'], color='black', linestyle='--',
                label=f'Best Val Acc (Epoch {outcome["best_epoch"]})')

    plt.title(f"{model_name} (Best LR={outcome['best_lr']})")
    plt.xlabel('Epoch')
    plt.ylabel('Loss / Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# Training CNN_10K:
#
#   Training with Learning Rate = 0.001
# CNN with (conv1_out=4, conv2_out=8, fc_dim=45): Total params=9841
#     Epoch [1/20] Train Loss: 0.8757  Train Acc: 0.6859 Val Loss: 0.5370  Val Acc: 0.7993
#     Epoch [2/20] Train Loss: 0.5602  Train Acc: 0.7911 Val Loss: 0.4641  Val Acc: 0.8297
#     Epoch [3/20] Train Loss: 0.5031  Train Acc: 0.8153 Val Loss: 0.4426  Val Acc: 0.8400
#     Epoch [4/20] Train Loss: 0.4698  Train Acc: 0.8285 Val Loss: 0.4054  Val Acc: 0.8530
#     Epoch [5/20] Train Loss: 0.4487  Train Acc: 0.8376 Val Loss: 0.3957  Val Acc: 0.8597
#     Epoch [6/20] Train Loss: 0.4368  Train Acc: 0.8412 Val Loss: 0.3862  Val Acc: 0.8613
#     Epoch [7/20] Train Loss: 0.4218  Train Acc: 0.8453 Val Loss: 0.3671  Val Acc: 0.8667
#     Epoch [8/20] Train Loss: 0.4122  Train Acc: 0.8504 Val Loss: 0.3607  Val Acc: 0.8667
#     Epoch [9/20] Train Loss: 0.4015  Train Acc: 0.8530 Val Loss: 0.3562  Val Acc: 0.8718
#     Epoch [10/20] Train Loss: 0.3994  Train Acc: 0.8549 Val Loss: 0.3476  Val Acc: 0.8737
#     Epoch [11/20] Train Loss: 0.3833  Train Acc: 0.8624 Val Loss: 0.3439  Val Acc: 0.8732
#     Epoch [12/20] Train Loss: 0.3803  Train Acc: 0.8629 Val Loss: 0.3401  Val Acc: 0.8768
#     Epoch [13/20] Train Loss: 0.3766  Train Acc: 0.8649 Val Loss: 0.3415  Val Acc: 0.8745
#     Epoch [14/20] Train Loss: 0.3726  Train Acc: 0.8642 Val Loss: 0.3362  Val Acc: 0.8780
#     Epoch [15/20] Train Loss: 0.3700  Train Acc: 0.8659 Val Loss: 0.3392  Val Acc: 0.8770
#     Epoch [16/20] Train Loss: 0.3684  Train Acc: 0.8668 Val Loss: 0.3371  Val Acc: 0.8762
#     Epoch [17/20] Train Loss: 0.3658  Train Acc: 0.8654 Val Loss: 0.3298  Val Acc: 0.8785
#     Epoch [18/20] Train Loss: 0.3618  Train Acc: 0.8684 Val Loss: 0.3349  Val Acc: 0.8790
#     Epoch [19/20] Train Loss: 0.3632  Train Acc: 0.8688 Val Loss: 0.3310  Val Acc: 0.8782
#     Epoch [20/20] Train Loss: 0.3586  Train Acc: 0.8700 Val Loss: 0.3300  Val Acc: 0.8827
#
#   Training with Learning Rate = 0.0005
# CNN with (conv1_out=4, conv2_out=8, fc_dim=45): Total params=9841
#     Epoch [1/20] Train Loss: 1.1018  Train Acc: 0.6128 Val Loss: 0.6273  Val Acc: 0.7678
#     Epoch [2/20] Train Loss: 0.6570  Train Acc: 0.7565 Val Loss: 0.5431  Val Acc: 0.7940
#     Epoch [3/20] Train Loss: 0.5903  Train Acc: 0.7827 Val Loss: 0.5046  Val Acc: 0.8150
#     Epoch [4/20] Train Loss: 0.5573  Train Acc: 0.7970 Val Loss: 0.4730  Val Acc: 0.8322
#     Epoch [5/20] Train Loss: 0.5306  Train Acc: 0.8060 Val Loss: 0.4546  Val Acc: 0.8358
#     Epoch [6/20] Train Loss: 0.5134  Train Acc: 0.8121 Val Loss: 0.4496  Val Acc: 0.8367
#     Epoch [7/20] Train Loss: 0.5011  Train Acc: 0.8172 Val Loss: 0.4312  Val Acc: 0.8462
#     Epoch [8/20] Train Loss: 0.4870  Train Acc: 0.8230 Val Loss: 0.4275  Val Acc: 0.8415
#     Epoch [9/20] Train Loss: 0.4811  Train Acc: 0.8248 Val Loss: 0.4167  Val Acc: 0.8567
#     Epoch [10/20] Train Loss: 0.4696  Train Acc: 0.8284 Val Loss: 0.4082  Val Acc: 0.8512
#     Epoch [11/20] Train Loss: 0.4555  Train Acc: 0.8344 Val Loss: 0.3987  Val Acc: 0.8598
#     Epoch [12/20] Train Loss: 0.4535  Train Acc: 0.8362 Val Loss: 0.3968  Val Acc: 0.8562
#     Epoch [13/20] Train Loss: 0.4527  Train Acc: 0.8359 Val Loss: 0.3967  Val Acc: 0.8560
#     Epoch [14/20] Train Loss: 0.4470  Train Acc: 0.8369 Val Loss: 0.3970  Val Acc: 0.8570
#     Epoch [15/20] Train Loss: 0.4461  Train Acc: 0.8383 Val Loss: 0.3941  Val Acc: 0.8557
#     Epoch [16/20] Train Loss: 0.4405  Train Acc: 0.8392 Val Loss: 0.3919  Val Acc: 0.8612
#     Epoch [17/20] Train Loss: 0.4405  Train Acc: 0.8396 Val Loss: 0.3851  Val Acc: 0.8628
#     Epoch [18/20] Train Loss: 0.4368  Train Acc: 0.8409 Val Loss: 0.3831  Val Acc: 0.8612
#     Epoch [19/20] Train Loss: 0.4351  Train Acc: 0.8415 Val Loss: 0.3815  Val Acc: 0.8625
#     Epoch [20/20] Train Loss: 0.4333  Train Acc: 0.8433 Val Loss: 0.3813  Val Acc: 0.8588
#
#   Training with Learning Rate = 0.0001
# CNN with (conv1_out=4, conv2_out=8, fc_dim=45): Total params=9841
#     Epoch [1/20] Train Loss: 1.7750  Train Acc: 0.4002 Val Loss: 1.1058  Val Acc: 0.6135
#     Epoch [2/20] Train Loss: 1.0455  Train Acc: 0.6105 Val Loss: 0.8555  Val Acc: 0.7017
#     Epoch [3/20] Train Loss: 0.8786  Train Acc: 0.6754 Val Loss: 0.7592  Val Acc: 0.7332
#     Epoch [4/20] Train Loss: 0.7962  Train Acc: 0.7023 Val Loss: 0.7037  Val Acc: 0.7448
#     Epoch [5/20] Train Loss: 0.7469  Train Acc: 0.7198 Val Loss: 0.6625  Val Acc: 0.7560
#     Epoch [6/20] Train Loss: 0.7079  Train Acc: 0.7337 Val Loss: 0.6318  Val Acc: 0.7657
#     Epoch [7/20] Train Loss: 0.6774  Train Acc: 0.7442 Val Loss: 0.6090  Val Acc: 0.7715
#     Epoch [8/20] Train Loss: 0.6528  Train Acc: 0.7528 Val Loss: 0.5866  Val Acc: 0.7818
#     Epoch [9/20] Train Loss: 0.6319  Train Acc: 0.7630 Val Loss: 0.5701  Val Acc: 0.7897
#     Epoch [10/20] Train Loss: 0.6131  Train Acc: 0.7694 Val Loss: 0.5551  Val Acc: 0.7890
#     Epoch [11/20] Train Loss: 0.6017  Train Acc: 0.7741 Val Loss: 0.5454  Val Acc: 0.7930
#     Epoch [12/20] Train Loss: 0.5909  Train Acc: 0.7783 Val Loss: 0.5389  Val Acc: 0.8018
#     Epoch [13/20] Train Loss: 0.5876  Train Acc: 0.7796 Val Loss: 0.5340  Val Acc: 0.8008
#     Epoch [14/20] Train Loss: 0.5810  Train Acc: 0.7826 Val Loss: 0.5261  Val Acc: 0.8047
#     Epoch [15/20] Train Loss: 0.5765  Train Acc: 0.7840 Val Loss: 0.5222  Val Acc: 0.8052
#     Epoch [16/20] Train Loss: 0.5709  Train Acc: 0.7872 Val Loss: 0.5171  Val Acc: 0.8092
#     Epoch [17/20] Train Loss: 0.5644  Train Acc: 0.7879 Val Loss: 0.5121  Val Acc: 0.8108
#     Epoch [18/20] Train Loss: 0.5597  Train Acc: 0.7898 Val Loss: 0.5084  Val Acc: 0.8105
#     Epoch [19/20] Train Loss: 0.5526  Train Acc: 0.7924 Val Loss: 0.5040  Val Acc: 0.8170
#     Epoch [20/20] Train Loss: 0.5512  Train Acc: 0.7931 Val Loss: 0.5009  Val Acc: 0.8147
# CNN with (conv1_out=4, conv2_out=8, fc_dim=45): Total params=9841
# --- CNN_10K Results ---
# Best Learning Rate: 0.001
# Best Validation Accuracy: 0.8827 (Epoch 20)
# Test Accuracy: 0.8736
# Training CNN_20K:
#
#   Training with Learning Rate = 0.001
# CNN with (conv1_out=6, conv2_out=12, fc_dim=60): Total params=19390
#     Epoch [1/20] Train Loss: 0.7992  Train Acc: 0.7121 Val Loss: 0.5052  Val Acc: 0.8157
#     Epoch [2/20] Train Loss: 0.5154  Train Acc: 0.8094 Val Loss: 0.4333  Val Acc: 0.8440
#     Epoch [3/20] Train Loss: 0.4582  Train Acc: 0.8303 Val Loss: 0.4015  Val Acc: 0.8547
#     Epoch [4/20] Train Loss: 0.4242  Train Acc: 0.8450 Val Loss: 0.3748  Val Acc: 0.8637
#     Epoch [5/20] Train Loss: 0.4034  Train Acc: 0.8521 Val Loss: 0.3594  Val Acc: 0.8695
#     Epoch [6/20] Train Loss: 0.3840  Train Acc: 0.8599 Val Loss: 0.3605  Val Acc: 0.8697
#     Epoch [7/20] Train Loss: 0.3732  Train Acc: 0.8643 Val Loss: 0.3339  Val Acc: 0.8822
#     Epoch [8/20] Train Loss: 0.3642  Train Acc: 0.8663 Val Loss: 0.3281  Val Acc: 0.8795
#     Epoch [9/20] Train Loss: 0.3531  Train Acc: 0.8720 Val Loss: 0.3296  Val Acc: 0.8797
#     Epoch [10/20] Train Loss: 0.3482  Train Acc: 0.8736 Val Loss: 0.3287  Val Acc: 0.8855
#     Epoch [11/20] Train Loss: 0.3309  Train Acc: 0.8802 Val Loss: 0.3148  Val Acc: 0.8853
#     Epoch [12/20] Train Loss: 0.3257  Train Acc: 0.8812 Val Loss: 0.3100  Val Acc: 0.8885
#     Epoch [13/20] Train Loss: 0.3204  Train Acc: 0.8829 Val Loss: 0.3072  Val Acc: 0.8902
#     Epoch [14/20] Train Loss: 0.3174  Train Acc: 0.8829 Val Loss: 0.3081  Val Acc: 0.8917
#     Epoch [15/20] Train Loss: 0.3128  Train Acc: 0.8857 Val Loss: 0.3079  Val Acc: 0.8915
#     Epoch [16/20] Train Loss: 0.3131  Train Acc: 0.8856 Val Loss: 0.3036  Val Acc: 0.8927
#     Epoch [17/20] Train Loss: 0.3111  Train Acc: 0.8870 Val Loss: 0.3002  Val Acc: 0.8927
#     Epoch [18/20] Train Loss: 0.3058  Train Acc: 0.8890 Val Loss: 0.3004  Val Acc: 0.8933
#     Epoch [19/20] Train Loss: 0.3041  Train Acc: 0.8882 Val Loss: 0.2950  Val Acc: 0.8943
#     Epoch [20/20] Train Loss: 0.3024  Train Acc: 0.8890 Val Loss: 0.3053  Val Acc: 0.8887
#
#   Training with Learning Rate = 0.0005
# CNN with (conv1_out=6, conv2_out=12, fc_dim=60): Total params=19390
#     Epoch [1/20] Train Loss: 0.9727  Train Acc: 0.6686 Val Loss: 0.5672  Val Acc: 0.7870
#     Epoch [2/20] Train Loss: 0.5726  Train Acc: 0.7901 Val Loss: 0.4812  Val Acc: 0.8247
#     Epoch [3/20] Train Loss: 0.5003  Train Acc: 0.8194 Val Loss: 0.4352  Val Acc: 0.8428
#     Epoch [4/20] Train Loss: 0.4600  Train Acc: 0.8326 Val Loss: 0.4070  Val Acc: 0.8540
#     Epoch [5/20] Train Loss: 0.4362  Train Acc: 0.8430 Val Loss: 0.3890  Val Acc: 0.8587
#     Epoch [6/20] Train Loss: 0.4160  Train Acc: 0.8489 Val Loss: 0.3747  Val Acc: 0.8635
#     Epoch [7/20] Train Loss: 0.4031  Train Acc: 0.8534 Val Loss: 0.3716  Val Acc: 0.8647
#     Epoch [8/20] Train Loss: 0.3912  Train Acc: 0.8572 Val Loss: 0.3538  Val Acc: 0.8700
#     Epoch [9/20] Train Loss: 0.3832  Train Acc: 0.8609 Val Loss: 0.3463  Val Acc: 0.8752
#     Epoch [10/20] Train Loss: 0.3745  Train Acc: 0.8631 Val Loss: 0.3463  Val Acc: 0.8720
#     Epoch [11/20] Train Loss: 0.3615  Train Acc: 0.8688 Val Loss: 0.3370  Val Acc: 0.8782
#     Epoch [12/20] Train Loss: 0.3562  Train Acc: 0.8713 Val Loss: 0.3335  Val Acc: 0.8793
#     Epoch [13/20] Train Loss: 0.3535  Train Acc: 0.8734 Val Loss: 0.3299  Val Acc: 0.8778
#     Epoch [14/20] Train Loss: 0.3499  Train Acc: 0.8735 Val Loss: 0.3292  Val Acc: 0.8793
#     Epoch [15/20] Train Loss: 0.3466  Train Acc: 0.8737 Val Loss: 0.3239  Val Acc: 0.8812
#     Epoch [16/20] Train Loss: 0.3423  Train Acc: 0.8745 Val Loss: 0.3247  Val Acc: 0.8813
#     Epoch [17/20] Train Loss: 0.3415  Train Acc: 0.8759 Val Loss: 0.3203  Val Acc: 0.8817
#     Epoch [18/20] Train Loss: 0.3361  Train Acc: 0.8773 Val Loss: 0.3187  Val Acc: 0.8852
#     Epoch [19/20] Train Loss: 0.3344  Train Acc: 0.8780 Val Loss: 0.3183  Val Acc: 0.8840
#     Epoch [20/20] Train Loss: 0.3336  Train Acc: 0.8795 Val Loss: 0.3162  Val Acc: 0.8857
#
#   Training with Learning Rate = 0.0001
# CNN with (conv1_out=6, conv2_out=12, fc_dim=60): Total params=19390
#     Epoch [1/20] Train Loss: 1.5857  Train Acc: 0.4818 Val Loss: 0.8964  Val Acc: 0.7162
#     Epoch [2/20] Train Loss: 0.8554  Train Acc: 0.6941 Val Loss: 0.6942  Val Acc: 0.7522
#     Epoch [3/20] Train Loss: 0.7211  Train Acc: 0.7345 Val Loss: 0.6173  Val Acc: 0.7722
#     Epoch [4/20] Train Loss: 0.6537  Train Acc: 0.7571 Val Loss: 0.5730  Val Acc: 0.7820
#     Epoch [5/20] Train Loss: 0.6167  Train Acc: 0.7719 Val Loss: 0.5416  Val Acc: 0.7960
#     Epoch [6/20] Train Loss: 0.5852  Train Acc: 0.7831 Val Loss: 0.5195  Val Acc: 0.8058
#     Epoch [7/20] Train Loss: 0.5633  Train Acc: 0.7905 Val Loss: 0.5001  Val Acc: 0.8200
#     Epoch [8/20] Train Loss: 0.5431  Train Acc: 0.7989 Val Loss: 0.4849  Val Acc: 0.8238
#     Epoch [9/20] Train Loss: 0.5275  Train Acc: 0.8059 Val Loss: 0.4718  Val Acc: 0.8283
#     Epoch [10/20] Train Loss: 0.5158  Train Acc: 0.8115 Val Loss: 0.4614  Val Acc: 0.8322
#     Epoch [11/20] Train Loss: 0.5027  Train Acc: 0.8153 Val Loss: 0.4556  Val Acc: 0.8352
#     Epoch [12/20] Train Loss: 0.4983  Train Acc: 0.8180 Val Loss: 0.4528  Val Acc: 0.8360
#     Epoch [13/20] Train Loss: 0.4903  Train Acc: 0.8200 Val Loss: 0.4445  Val Acc: 0.8390
#     Epoch [14/20] Train Loss: 0.4868  Train Acc: 0.8212 Val Loss: 0.4416  Val Acc: 0.8412
#     Epoch [15/20] Train Loss: 0.4813  Train Acc: 0.8243 Val Loss: 0.4380  Val Acc: 0.8420
#     Epoch [16/20] Train Loss: 0.4786  Train Acc: 0.8259 Val Loss: 0.4336  Val Acc: 0.8423
#     Epoch [17/20] Train Loss: 0.4738  Train Acc: 0.8272 Val Loss: 0.4317  Val Acc: 0.8462
#     Epoch [18/20] Train Loss: 0.4698  Train Acc: 0.8292 Val Loss: 0.4256  Val Acc: 0.8455
#     Epoch [19/20] Train Loss: 0.4669  Train Acc: 0.8310 Val Loss: 0.4260  Val Acc: 0.8457
#     Epoch [20/20] Train Loss: 0.4621  Train Acc: 0.8323 Val Loss: 0.4223  Val Acc: 0.8460
# CNN with (conv1_out=6, conv2_out=12, fc_dim=60): Total params=19390
# --- CNN_20K Results ---
# Best Learning Rate: 0.001
# Best Validation Accuracy: 0.8943 (Epoch 19)
# Test Accuracy: 0.8862
# Training CNN_50K:
#
#   Training with Learning Rate = 0.001
# CNN with (conv1_out=8, conv2_out=16, fc_dim=120): Total params=50578
#     Epoch [1/20] Train Loss: 0.7016  Train Acc: 0.7464 Val Loss: 0.4528  Val Acc: 0.8380
#     Epoch [2/20] Train Loss: 0.4631  Train Acc: 0.8302 Val Loss: 0.3859  Val Acc: 0.8657
#     Epoch [3/20] Train Loss: 0.4093  Train Acc: 0.8521 Val Loss: 0.3572  Val Acc: 0.8675
#     Epoch [4/20] Train Loss: 0.3724  Train Acc: 0.8646 Val Loss: 0.3303  Val Acc: 0.8825
#     Epoch [5/20] Train Loss: 0.3469  Train Acc: 0.8729 Val Loss: 0.3118  Val Acc: 0.8857
#     Epoch [6/20] Train Loss: 0.3315  Train Acc: 0.8775 Val Loss: 0.3128  Val Acc: 0.8820
#     Epoch [7/20] Train Loss: 0.3172  Train Acc: 0.8847 Val Loss: 0.3016  Val Acc: 0.8872
#     Epoch [8/20] Train Loss: 0.3029  Train Acc: 0.8877 Val Loss: 0.2925  Val Acc: 0.8910
#     Epoch [9/20] Train Loss: 0.2940  Train Acc: 0.8924 Val Loss: 0.2867  Val Acc: 0.8915
#     Epoch [10/20] Train Loss: 0.2867  Train Acc: 0.8945 Val Loss: 0.2966  Val Acc: 0.8917
#     Epoch [11/20] Train Loss: 0.2668  Train Acc: 0.9005 Val Loss: 0.2703  Val Acc: 0.9008
#     Epoch [12/20] Train Loss: 0.2603  Train Acc: 0.9044 Val Loss: 0.2776  Val Acc: 0.8972
#     Epoch [13/20] Train Loss: 0.2550  Train Acc: 0.9054 Val Loss: 0.2801  Val Acc: 0.8975
#     Epoch [14/20] Train Loss: 0.2534  Train Acc: 0.9049 Val Loss: 0.2650  Val Acc: 0.9040
#     Epoch [15/20] Train Loss: 0.2492  Train Acc: 0.9069 Val Loss: 0.2647  Val Acc: 0.9027
#     Epoch [16/20] Train Loss: 0.2459  Train Acc: 0.9085 Val Loss: 0.2670  Val Acc: 0.9020
#     Epoch [17/20] Train Loss: 0.2413  Train Acc: 0.9105 Val Loss: 0.2661  Val Acc: 0.9042
#     Epoch [18/20] Train Loss: 0.2367  Train Acc: 0.9114 Val Loss: 0.2608  Val Acc: 0.9068
#     Epoch [19/20] Train Loss: 0.2341  Train Acc: 0.9125 Val Loss: 0.2604  Val Acc: 0.9052
#     Epoch [20/20] Train Loss: 0.2318  Train Acc: 0.9135 Val Loss: 0.2594  Val Acc: 0.9058
#
#   Training with Learning Rate = 0.0005
# CNN with (conv1_out=8, conv2_out=16, fc_dim=120): Total params=50578
#     Epoch [1/20] Train Loss: 0.8059  Train Acc: 0.7144 Val Loss: 0.5022  Val Acc: 0.8133
#     Epoch [2/20] Train Loss: 0.4914  Train Acc: 0.8167 Val Loss: 0.4232  Val Acc: 0.8438
#     Epoch [3/20] Train Loss: 0.4360  Train Acc: 0.8405 Val Loss: 0.3819  Val Acc: 0.8607
#     Epoch [4/20] Train Loss: 0.4007  Train Acc: 0.8537 Val Loss: 0.3721  Val Acc: 0.8637
#     Epoch [5/20] Train Loss: 0.3794  Train Acc: 0.8619 Val Loss: 0.3406  Val Acc: 0.8745
#     Epoch [6/20] Train Loss: 0.3608  Train Acc: 0.8683 Val Loss: 0.3328  Val Acc: 0.8807
#     Epoch [7/20] Train Loss: 0.3493  Train Acc: 0.8718 Val Loss: 0.3241  Val Acc: 0.8827
#     Epoch [8/20] Train Loss: 0.3364  Train Acc: 0.8767 Val Loss: 0.3189  Val Acc: 0.8852
#     Epoch [9/20] Train Loss: 0.3266  Train Acc: 0.8801 Val Loss: 0.3174  Val Acc: 0.8825
#     Epoch [10/20] Train Loss: 0.3169  Train Acc: 0.8839 Val Loss: 0.3016  Val Acc: 0.8910
#     Epoch [11/20] Train Loss: 0.3017  Train Acc: 0.8897 Val Loss: 0.2970  Val Acc: 0.8912
#     Epoch [12/20] Train Loss: 0.2967  Train Acc: 0.8919 Val Loss: 0.2962  Val Acc: 0.8913
#     Epoch [13/20] Train Loss: 0.2921  Train Acc: 0.8926 Val Loss: 0.2930  Val Acc: 0.8918
#     Epoch [14/20] Train Loss: 0.2890  Train Acc: 0.8942 Val Loss: 0.2928  Val Acc: 0.8948
#     Epoch [15/20] Train Loss: 0.2856  Train Acc: 0.8947 Val Loss: 0.2884  Val Acc: 0.8942
#     Epoch [16/20] Train Loss: 0.2826  Train Acc: 0.8972 Val Loss: 0.2871  Val Acc: 0.8928
#     Epoch [17/20] Train Loss: 0.2812  Train Acc: 0.8974 Val Loss: 0.2867  Val Acc: 0.8960
#     Epoch [18/20] Train Loss: 0.2757  Train Acc: 0.8981 Val Loss: 0.2804  Val Acc: 0.8963
#     Epoch [19/20] Train Loss: 0.2732  Train Acc: 0.8988 Val Loss: 0.2820  Val Acc: 0.8980
#     Epoch [20/20] Train Loss: 0.2717  Train Acc: 0.9000 Val Loss: 0.2821  Val Acc: 0.8962
#
#   Training with Learning Rate = 0.0001
# CNN with (conv1_out=8, conv2_out=16, fc_dim=120): Total params=50578
#     Epoch [1/20] Train Loss: 1.3261  Train Acc: 0.5835 Val Loss: 0.7490  Val Acc: 0.7463
#     Epoch [2/20] Train Loss: 0.7107  Train Acc: 0.7427 Val Loss: 0.6036  Val Acc: 0.7853
#     Epoch [3/20] Train Loss: 0.6062  Train Acc: 0.7780 Val Loss: 0.5381  Val Acc: 0.8095
#     Epoch [4/20] Train Loss: 0.5551  Train Acc: 0.7974 Val Loss: 0.5028  Val Acc: 0.8177
#     Epoch [5/20] Train Loss: 0.5218  Train Acc: 0.8085 Val Loss: 0.4763  Val Acc: 0.8303
#     Epoch [6/20] Train Loss: 0.4981  Train Acc: 0.8188 Val Loss: 0.4538  Val Acc: 0.8353
#     Epoch [7/20] Train Loss: 0.4781  Train Acc: 0.8249 Val Loss: 0.4410  Val Acc: 0.8430
#     Epoch [8/20] Train Loss: 0.4634  Train Acc: 0.8317 Val Loss: 0.4295  Val Acc: 0.8470
#     Epoch [9/20] Train Loss: 0.4500  Train Acc: 0.8364 Val Loss: 0.4156  Val Acc: 0.8507
#     Epoch [10/20] Train Loss: 0.4378  Train Acc: 0.8396 Val Loss: 0.4093  Val Acc: 0.8543
#     Epoch [11/20] Train Loss: 0.4284  Train Acc: 0.8440 Val Loss: 0.4028  Val Acc: 0.8547
#     Epoch [12/20] Train Loss: 0.4223  Train Acc: 0.8459 Val Loss: 0.3981  Val Acc: 0.8570
#     Epoch [13/20] Train Loss: 0.4178  Train Acc: 0.8474 Val Loss: 0.3936  Val Acc: 0.8587
#     Epoch [14/20] Train Loss: 0.4147  Train Acc: 0.8493 Val Loss: 0.3916  Val Acc: 0.8587
#     Epoch [15/20] Train Loss: 0.4098  Train Acc: 0.8500 Val Loss: 0.3867  Val Acc: 0.8615
#     Epoch [16/20] Train Loss: 0.4077  Train Acc: 0.8518 Val Loss: 0.3815  Val Acc: 0.8623
#     Epoch [17/20] Train Loss: 0.4016  Train Acc: 0.8543 Val Loss: 0.3786  Val Acc: 0.8637
#     Epoch [18/20] Train Loss: 0.3977  Train Acc: 0.8549 Val Loss: 0.3761  Val Acc: 0.8655
#     Epoch [19/20] Train Loss: 0.3949  Train Acc: 0.8557 Val Loss: 0.3754  Val Acc: 0.8673
#     Epoch [20/20] Train Loss: 0.3925  Train Acc: 0.8559 Val Loss: 0.3713  Val Acc: 0.8677
# CNN with (conv1_out=8, conv2_out=16, fc_dim=120): Total params=50578
# --- CNN_50K Results ---
# Best Learning Rate: 0.001
# Best Validation Accuracy: 0.9068 (Epoch 18)
# Test Accuracy: 0.9023
# Training CNN_100K:
#
#   Training with Learning Rate = 0.001
# CNN with (conv1_out=16, conv2_out=32, fc_dim=120): Total params=102130
#     Epoch [1/20] Train Loss: 0.6236  Train Acc: 0.7716 Val Loss: 0.4137  Val Acc: 0.8478
#     Epoch [2/20] Train Loss: 0.3966  Train Acc: 0.8551 Val Loss: 0.3376  Val Acc: 0.8785
#     Epoch [3/20] Train Loss: 0.3481  Train Acc: 0.8721 Val Loss: 0.3078  Val Acc: 0.8868
#     Epoch [4/20] Train Loss: 0.3199  Train Acc: 0.8823 Val Loss: 0.2956  Val Acc: 0.8900
#     Epoch [5/20] Train Loss: 0.2976  Train Acc: 0.8917 Val Loss: 0.2879  Val Acc: 0.8933
#     Epoch [6/20] Train Loss: 0.2829  Train Acc: 0.8956 Val Loss: 0.2718  Val Acc: 0.8990
#     Epoch [7/20] Train Loss: 0.2697  Train Acc: 0.9007 Val Loss: 0.2704  Val Acc: 0.9015
#     Epoch [8/20] Train Loss: 0.2569  Train Acc: 0.9039 Val Loss: 0.2711  Val Acc: 0.8988
#     Epoch [9/20] Train Loss: 0.2446  Train Acc: 0.9098 Val Loss: 0.2661  Val Acc: 0.9015
#     Epoch [10/20] Train Loss: 0.2402  Train Acc: 0.9116 Val Loss: 0.2560  Val Acc: 0.9058
#     Epoch [11/20] Train Loss: 0.2120  Train Acc: 0.9222 Val Loss: 0.2438  Val Acc: 0.9103
#     Epoch [12/20] Train Loss: 0.2049  Train Acc: 0.9241 Val Loss: 0.2460  Val Acc: 0.9097
#     Epoch [13/20] Train Loss: 0.2000  Train Acc: 0.9255 Val Loss: 0.2415  Val Acc: 0.9128
#     Epoch [14/20] Train Loss: 0.1945  Train Acc: 0.9280 Val Loss: 0.2528  Val Acc: 0.9083
#     Epoch [15/20] Train Loss: 0.1903  Train Acc: 0.9289 Val Loss: 0.2442  Val Acc: 0.9120
#     Epoch [16/20] Train Loss: 0.1831  Train Acc: 0.9313 Val Loss: 0.2441  Val Acc: 0.9118
#     Epoch [17/20] Train Loss: 0.1792  Train Acc: 0.9341 Val Loss: 0.2443  Val Acc: 0.9133
#     Epoch [18/20] Train Loss: 0.1720  Train Acc: 0.9350 Val Loss: 0.2410  Val Acc: 0.9147
#     Epoch [19/20] Train Loss: 0.1704  Train Acc: 0.9348 Val Loss: 0.2457  Val Acc: 0.9138
#     Epoch [20/20] Train Loss: 0.1658  Train Acc: 0.9382 Val Loss: 0.2438  Val Acc: 0.9162
#
#   Training with Learning Rate = 0.0005
# CNN with (conv1_out=16, conv2_out=32, fc_dim=120): Total params=102130
#     Epoch [1/20] Train Loss: 0.7109  Train Acc: 0.7447 Val Loss: 0.4520  Val Acc: 0.8347
#     Epoch [2/20] Train Loss: 0.4478  Train Acc: 0.8379 Val Loss: 0.3930  Val Acc: 0.8560
#     Epoch [3/20] Train Loss: 0.3851  Train Acc: 0.8600 Val Loss: 0.3583  Val Acc: 0.8728
#     Epoch [4/20] Train Loss: 0.3522  Train Acc: 0.8733 Val Loss: 0.3214  Val Acc: 0.8818
#     Epoch [5/20] Train Loss: 0.3289  Train Acc: 0.8816 Val Loss: 0.3194  Val Acc: 0.8843
#     Epoch [6/20] Train Loss: 0.3141  Train Acc: 0.8854 Val Loss: 0.3175  Val Acc: 0.8807
#     Epoch [7/20] Train Loss: 0.2997  Train Acc: 0.8907 Val Loss: 0.2966  Val Acc: 0.8908
#     Epoch [8/20] Train Loss: 0.2888  Train Acc: 0.8950 Val Loss: 0.2960  Val Acc: 0.8930
#     Epoch [9/20] Train Loss: 0.2790  Train Acc: 0.8988 Val Loss: 0.2734  Val Acc: 0.9005
#     Epoch [10/20] Train Loss: 0.2692  Train Acc: 0.9007 Val Loss: 0.2650  Val Acc: 0.9022
#     Epoch [11/20] Train Loss: 0.2497  Train Acc: 0.9077 Val Loss: 0.2579  Val Acc: 0.9053
#     Epoch [12/20] Train Loss: 0.2446  Train Acc: 0.9105 Val Loss: 0.2531  Val Acc: 0.9048
#     Epoch [13/20] Train Loss: 0.2395  Train Acc: 0.9119 Val Loss: 0.2556  Val Acc: 0.9063
#     Epoch [14/20] Train Loss: 0.2365  Train Acc: 0.9130 Val Loss: 0.2506  Val Acc: 0.9070
#     Epoch [15/20] Train Loss: 0.2322  Train Acc: 0.9154 Val Loss: 0.2505  Val Acc: 0.9090
#     Epoch [16/20] Train Loss: 0.2271  Train Acc: 0.9179 Val Loss: 0.2471  Val Acc: 0.9103
#     Epoch [17/20] Train Loss: 0.2236  Train Acc: 0.9181 Val Loss: 0.2482  Val Acc: 0.9105
#     Epoch [18/20] Train Loss: 0.2194  Train Acc: 0.9200 Val Loss: 0.2464  Val Acc: 0.9093
#     Epoch [19/20] Train Loss: 0.2165  Train Acc: 0.9204 Val Loss: 0.2453  Val Acc: 0.9093
#     Epoch [20/20] Train Loss: 0.2128  Train Acc: 0.9218 Val Loss: 0.2429  Val Acc: 0.9105
#
#   Training with Learning Rate = 0.0001
# CNN with (conv1_out=16, conv2_out=32, fc_dim=120): Total params=102130
#     Epoch [1/20] Train Loss: 1.0924  Train Acc: 0.6487 Val Loss: 0.6478  Val Acc: 0.7668
#     Epoch [2/20] Train Loss: 0.6237  Train Acc: 0.7689 Val Loss: 0.5320  Val Acc: 0.8042
#     Epoch [3/20] Train Loss: 0.5377  Train Acc: 0.8012 Val Loss: 0.4774  Val Acc: 0.8267
#     Epoch [4/20] Train Loss: 0.4901  Train Acc: 0.8205 Val Loss: 0.4486  Val Acc: 0.8403
#     Epoch [5/20] Train Loss: 0.4582  Train Acc: 0.8331 Val Loss: 0.4208  Val Acc: 0.8498
#     Epoch [6/20] Train Loss: 0.4352  Train Acc: 0.8422 Val Loss: 0.3974  Val Acc: 0.8600
#     Epoch [7/20] Train Loss: 0.4158  Train Acc: 0.8494 Val Loss: 0.3934  Val Acc: 0.8577
#     Epoch [8/20] Train Loss: 0.4020  Train Acc: 0.8548 Val Loss: 0.3804  Val Acc: 0.8622
#     Epoch [9/20] Train Loss: 0.3879  Train Acc: 0.8604 Val Loss: 0.3618  Val Acc: 0.8705
#     Epoch [10/20] Train Loss: 0.3761  Train Acc: 0.8644 Val Loss: 0.3558  Val Acc: 0.8717
#     Epoch [11/20] Train Loss: 0.3639  Train Acc: 0.8699 Val Loss: 0.3534  Val Acc: 0.8758
#     Epoch [12/20] Train Loss: 0.3590  Train Acc: 0.8703 Val Loss: 0.3464  Val Acc: 0.8742
#     Epoch [13/20] Train Loss: 0.3548  Train Acc: 0.8732 Val Loss: 0.3419  Val Acc: 0.8770
#     Epoch [14/20] Train Loss: 0.3509  Train Acc: 0.8734 Val Loss: 0.3405  Val Acc: 0.8760
#     Epoch [15/20] Train Loss: 0.3463  Train Acc: 0.8754 Val Loss: 0.3382  Val Acc: 0.8775
#     Epoch [16/20] Train Loss: 0.3429  Train Acc: 0.8752 Val Loss: 0.3347  Val Acc: 0.8798
#     Epoch [17/20] Train Loss: 0.3384  Train Acc: 0.8770 Val Loss: 0.3302  Val Acc: 0.8825
#     Epoch [18/20] Train Loss: 0.3342  Train Acc: 0.8793 Val Loss: 0.3284  Val Acc: 0.8817
#     Epoch [19/20] Train Loss: 0.3311  Train Acc: 0.8815 Val Loss: 0.3264  Val Acc: 0.8823
#     Epoch [20/20] Train Loss: 0.3277  Train Acc: 0.8831 Val Loss: 0.3182  Val Acc: 0.8845
# CNN with (conv1_out=16, conv2_out=32, fc_dim=120): Total params=102130
# --- CNN_100K Results ---
# Best Learning Rate: 0.001
# Best Validation Accuracy: 0.9162 (Epoch 20)
# Test Accuracy: 0.9104
